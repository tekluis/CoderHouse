# %% [markdown]
# # APIKEY

# %% [markdown]
# Como primera parte del desafío usaremos la API de Youtube, a través de una APIKEY creada según las indicaciones del proyecto.

# %%
from googleapiclient.discovery import build
import requests
import pandas as pd

api_key='AIzaSyAme7p4RvVQpXBiRdZDHVq2KJq5Nm7aHWk'
youtube= build('youtube','v3',developerKey=api_key)

request=youtube.channels().list(
    part='snippet,contentDetails,brandingSettings,topicDetails,status',
    forUsername= 'Simplilearn' 
)
response=request.execute()
print(response['items'])
# Out:
# [{'kind': 'youtube#channel', 'etag': '0ZZ24GGS-1WDQwqlRkqw60HQi5A', 'id': 'UCsvqVGtbbyHaMoevxPAq9Fg', 'snippet': {'title': 'Simplilearn', 'description': 'Simplilearn is the world’s #1 online Bootcamp and one of the world’s leading certification training providers. Based in San Francisco, California, and Bangalore, India, we provide training in areas where technologies and best practices are changing rapidly, and the demand for qualified candidates significantly exceeds the supply. We have trained over 3,000,000 professionals, have over 2000 qualified trainers on board, and offer over 400 courses with 40 plus global accreditations. With live instructions from leading experts, interactive labs & projects, peer-to-peer collaboration, on-demand lessons, and 24/7 learning support, we provide learners with a comprehensive curriculum at a fraction of the cost of an on-campus program. \n\nFor more information, visit https://www.simplilearn.com/\nOur FREE courses via SkillUp by Simplilearn no
# ...

# %% [markdown]
# Luego, separaremos los datos obtenidos para poder visualizarlos.

# %%
# Acceder a diferentes partes de la respuesta
snippet_info = response['items'][0]['snippet']
content_details = response['items'][0]['contentDetails']
branding_settings = response['items'][0]['brandingSettings']
topic_details = response['items'][0]['topicDetails']
status = response['items'][0]['status']

# Imprimir información relevante
print("Información básica (Snippet):")
print(snippet_info)
print("\nDetalles del contenido (ContentDetails):")
print(content_details)
print("\nConfiguración de marca (BrandingSettings):")
print(branding_settings)
print("\nTemas relacionados (TopicDetails):")
print(topic_details)
print("\nEstado del canal (Status):")
print(status)
# Out:
# Información básica (Snippet):
# ...

# %% [markdown]
# Por último, convertiremos los datos en dataframes.

# %%
df_snippet = pd.DataFrame(snippet_info)
df_snippet
# Out:
#                    title                                        description  \
# default      Simplilearn  Simplilearn is the world’s #1 online Bootcamp ...
# medium       Simplilearn  Simplilearn is the world’s #1 online Bootcamp ...
# high         Simplilearn  Simplilearn is the world’s #1 online Bootcamp ...
# title        Simplilearn  Simplilearn is the world’s #1 online Bootcamp ...
# description  Simplilearn  Simplilearn is the world’s #1 online Bootcamp ...
#
#                         customUrl           publishedAt  \
# default      @simplilearnofficial  2009-10-29T07:21:23Z
# medium       @simplilearnofficial  2009-10-29T07:21:23Z
# high         @simplilearnofficial  2009-10-29T07:21:23Z
# title        @simplilearnofficial  2009-10-29T07:21:23Z
# description  @simplilearnofficial  2009-10-29T07:21:23Z
#
#                                                     thumbnails  \
# default      {'url': 'https://yt3.ggpht.com/7q9t5rjeujEZYqY...
# ...

# %%
df_content_details = pd.DataFrame(content_details)
df_content_details
# Out:
#                  relatedPlaylists
# likes
# uploads  UUsvqVGtbbyHaMoevxPAq9Fg

# %%
df_branding_settings = pd.DataFrame(branding_settings)
df_branding_settings
# Out:
#                                                                       channel  \
# title                                                             Simplilearn
# description                 Simplilearn is the world’s #1 online Bootcamp ...
# keywords                    "cyber security" blockchain "digital marketing...
# trackingAnalyticsAccountId                                      UA-32079340-6
# unsubscribedTrailer                                               C2NQ0jScRno
# country                                                                    US
# bannerExternalUrl                                                         NaN
#
#                                                                         image
# title                                                                     NaN
# description                                                               NaN
# keywords                                                                  NaN
# ...

# %%
df_topic_details = pd.DataFrame(topic_details)
df_topic_details
# Out:
#     topicIds                                    topicCategories
# 0  /m/01k8wb            https://en.wikipedia.org/wiki/Knowledge
# 1  /m/019_rr  https://en.wikipedia.org/wiki/Lifestyle_(socio...
# 2   /m/07c1v           https://en.wikipedia.org/wiki/Technology

# %%
df_status = pd.DataFrame([status])
df_status
# Out:
#   privacyStatus  isLinked       longUploadsStatus  madeForKids
# 0        public      True  longUploadsUnspecified        False

# %% [markdown]
# # API PUBLICA

# %% [markdown]
# Repetiremos todo el proceso anterior, pero esta vez a través de una API pública.

# %%
import requests
import pandas as pd

# URL de la API JSONPlaceholder
api_url = 'https://jsonplaceholder.typicode.com/posts'

# Realizar una solicitud GET a la API
response = requests.get(api_url)

# Verificar si la solicitud fue exitosa (código de estado 200)
if response.status_code == 200:
    # Convertir la respuesta JSON en una lista de diccionarios
    data = response.json()
    
    # Crear un DataFrame a partir de la lista de diccionarios
    df = pd.DataFrame(data)
    
    # Mostrar información sobre el DataFrame
    print("Número de filas:", df.shape[0])
    print("Número de columnas:", df.shape[1])
    print("\nMuestra de datos:")
    print(df)
else:
    print("Error al realizar la solicitud a la API")
# Out:
# Número de filas: 100
# Número de columnas: 4
#
# Muestra de datos:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# ...
